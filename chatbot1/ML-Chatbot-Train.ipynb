# %% [markdown]
# https://dzone.com/articles/python-chatbot-project-build-your-first-python-pro

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

# %%
intents_file = open('intents.json').read()
intents = json.loads(intents_file)

# %% [markdown]
# ### Preprocessing the Data
#
# The model cannot take the raw data. It has to go through a lot of pre-processing for the machine to easily understand. For textual data, there are many preprocessing techniques available. The first technique is tokenizing, in which we break the sentences into words.
#
# By observing the intents file, we can see that each tag contains a list of patterns and responses. We tokenize each pattern and add the words in a list. Also, we create a list of classes and documents to add all the intents associated with patterns.

# %%
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)        

        #add documents in the corpus
        documents.append((word, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
            
print(documents)
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %% [markdown]
# Another technique is Lemmatization. We can convert words into the lemma form so that we can reduce all the canonical words. For example, the words play, playing, plays, played, etc. will all be replaced with play. This way, we can reduce the number of total words in our vocabulary. So now we lemmatize each word and remove the duplicate words.
#
# In the end, the words contain the vocabulary of our project and classes contain the total entities to classify. To save the python object in a file, we used the pickle.dump() method. These files will be helpful after the training is done and we predict the chats.

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %% [markdown]
# ### Create Training and Testing Data
# To train the model, we will convert each input pattern into numbers. First, we will lemmatize each word of the pattern and create a list of zeroes of the same length as the total number of words. We will set value 1 to only those indexes that contain the word in the patterns. In the same way, we will create the output by setting 1 to the class input the pattern belongs to.

# %%
# create the training data
training = []

# create empty array for the output
output_empty = [0] * len(classes)

# training set, bag of words for every sentence

for doc in documents:
    # initializing bag of words
    bag = []

    # list of tokenized words for the pattern
    word_patterns = doc[0]

    # lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]

    # create the bag of words array with 1, if word is found in current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
        
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)

# create training and testing lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data is created")
# Out:
# Training data is created
# <ipython-input-6-59697142df91>:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)

# %% [markdown]
# ### Training the Model
# The architecture of our model will be a neural network consisting of 3 dense layers. The first layer has 128 neurons, the second one has 64 and the last layer will have the same neurons as the number of classes. The dropout layers are introduced to reduce overfitting of the model. We have used the SGD optimizer and fit the data to start the training of the model. After the training of 200 epochs is completed, we then save the trained model using the Keras model.save(“chatbot_model.h5”) function.

# %%
# deep neural networds model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#Training and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model is created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s 1ms/step - loss: 2.2642 - accuracy: 0.0435
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1346 - accuracy: 0.0963
# Epoch 3/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1115 - accuracy: 0.1787
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1112 - accuracy: 0.2106
# Epoch 5/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.8408 - accuracy: 0.5278
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7080 - accuracy: 0.5588
# Epoch 7/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7797 - accuracy: 0.4641
# Epoch 8/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.5510 - accuracy: 0.5182
# Epoch 9/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.5316 - accuracy: 0.5672
# Epoch 10/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2230 - accuracy: 0.7227
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1457 - accuracy: 0.6632
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1763 - accuracy: 0.6736
# Epoch 13/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0826 - accuracy: 0.7268
# Epoch 14/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0776 - accuracy: 0.6622
# Epoch 15/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8821 - accuracy: 0.7422
# Epoch 16/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8497 - accuracy: 0.8084
# Epoch 17/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9772 - accuracy: 0.6346
# Epoch 18/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6141 - accuracy: 0.8291
# Epoch 19/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7447 - accuracy: 0.7854
# Epoch 20/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5029 - accuracy: 0.7590
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4377 - accuracy: 0.9185
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3206 - accuracy: 1.0000
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5525 - accuracy: 0.8601
# Epoch 24/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3250 - accuracy: 0.9080
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5916 - accuracy: 0.8161
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3383 - accuracy: 0.9404
# Epoch 27/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2088 - accuracy: 0.9859
# Epoch 28/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3412 - accuracy: 0.8663
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1783 - accuracy: 0.9143
# Epoch 30/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2886 - accuracy: 0.8926
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2153 - accuracy: 0.9464
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3109 - accuracy: 0.8644
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2939 - accuracy: 0.8909
# Epoch 34/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2067 - accuracy: 0.9604
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1988 - accuracy: 0.9169
# Epoch 36/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2308 - accuracy: 0.9961
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2656 - accuracy: 0.9408
# Epoch 38/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2058 - accuracy: 0.8856
# Epoch 39/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1684 - accuracy: 0.9721
# Epoch 40/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1522 - accuracy: 0.9961
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1636 - accuracy: 0.9892
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1169 - accuracy: 0.9826
# Epoch 43/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0993 - accuracy: 0.9892
# Epoch 44/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0996 - accuracy: 0.9677
# Epoch 45/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2760 - accuracy: 0.9211
# Epoch 46/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2405 - accuracy: 0.9306
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1674 - accuracy: 0.9582
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1040 - accuracy: 0.9918
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0935 - accuracy: 0.9826
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0627 - accuracy: 1.0000
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1997 - accuracy: 0.9393
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0743 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0921 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1308 - accuracy: 0.9941
# Epoch 55/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.9941
# Epoch 56/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0794 - accuracy: 1.0000
# Epoch 57/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0671 - accuracy: 0.9918
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0904 - accuracy: 0.9892
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0880 - accuracy: 0.9720
# Epoch 60/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0471 - accuracy: 0.9961
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1184 - accuracy: 0.9780
# Epoch 62/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1015 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1945 - accuracy: 0.9310
# Epoch 64/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0434 - accuracy: 0.9941
# Epoch 67/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2366 - accuracy: 0.9365
# Epoch 68/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0858 - accuracy: 0.9826
# Epoch 69/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0944 - accuracy: 0.9902
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0564 - accuracy: 0.9941
# Epoch 71/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1025 - accuracy: 0.9918
# Epoch 73/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1377 - accuracy: 0.9780
# Epoch 74/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0466 - accuracy: 0.9720
# Epoch 75/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1250 - accuracy: 0.9629
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0485 - accuracy: 0.9862
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1180 - accuracy: 0.9447
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0555 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0555 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0665 - accuracy: 0.9862
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 0.9918
# Epoch 82/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0388 - accuracy: 0.9941
# Epoch 83/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0841 - accuracy: 0.9720
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9447
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0434 - accuracy: 0.9780
# Epoch 90/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0921 - accuracy: 0.9892
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0411 - accuracy: 0.9862
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0555 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0567 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0921 - accuracy: 0.9892
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1337 - accuracy: 0.9447
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0481 - accuracy: 0.9629
# Epoch 106/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 0.9892
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1529 - accuracy: 0.9339
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9642
# Epoch 110/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0688 - accuracy: 0.9918
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0620 - accuracy: 0.9862
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0468 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 0.9862
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0760 - accuracy: 0.9892
# Epoch 122/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1139 - accuracy: 0.9447
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1030 - accuracy: 0.9826
# Epoch 124/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0918 - accuracy: 0.9447
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0489 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0651 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 0.9961
# Epoch 143/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 0.9803
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 0.9918
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9862
# Epoch 158/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2192 - accuracy: 0.9447
# Epoch 159/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0644 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0797 - accuracy: 0.9447
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0370 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0329 - accuracy: 0.9780
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 0.9918
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0672 - accuracy: 0.9918
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0682 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0361 - accuracy: 0.9826
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9862
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0697 - accuracy: 0.9365
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 0.9892
# Epoch 199/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 1.0000
# model is created
