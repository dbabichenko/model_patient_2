# %%
import pandas as pd

# %%
df = pd.read_csv('sepsis_events_sorted.csv')

# %%
df.shape
# Out:
# (6047543, 8)

# %%
df.head()
# Out:
#    Unnamed: 0                               eventId  \
# 0           0  cd4d6094-57b7-11e9-99cb-e51ddd026e24
# 1           1  dc98c872-57b7-11e9-99cb-e51ddd026e24
# 2           2  ea8ef398-57b7-11e9-99cb-e51ddd026e24
# 3           3  f877962c-57b7-11e9-99cb-e51ddd026e24
# 4           4  026b509c-57b8-11e9-99cb-e51ddd026e24
#
#                               patientId         eventDate         eventName  \
# 0  02298368-57b5-11e9-ad52-30582bd09167  2013-12-18T12:57      Diastolic BP
# 1  02298368-57b5-11e9-ad52-30582bd09167  2013-12-18T12:57     O2 Saturation
# 2  02298368-57b5-11e9-ad52-30582bd09167  2013-12-18T12:57             Pulse
# 3  02298368-57b5-11e9-ad52-30582bd09167  2013-12-18T12:57  Respiratory Rate
# 4  02298368-57b5-11e9-ad52-30582bd09167  2013-12-18T12:57       Systolic BP
#
#    resultValue resultUnit eventCategory
# 0         99.0       mmHg        vitals
# 1         98.0          %        vitals
# 2         72.0        BPM        vitals
# ...

# %%
for idx, row in df.head().iterrows():
    qry = "CREATE (e:Event { patientId: '" + row['patientId'] + "', "
    qry = qry + "eventId: '" + row['eventId'] + "', "
    qry = qry + "eventName: '" + row['eventName'] + "', "
    qry = qry + "eventCategory: '" + row['eventCategory'] + "', "
    qry = qry + "eventDate: '" + row['eventDate'] + "', "
    qry = qry + "resultValue: '" + str(row['resultValue']) + "', "
    qry = qry + "resultUnit: '" + row['resultUnit'] + "' "
    qry = qry + "});"
    print(qry)
    #row.patientId AS patientId, row.eventId AS eventId, row.eventName as eventName, 
    #row.eventCategory as eventCategory, row.eventDate AS eventDate, 
    #row.resultValue AS resultValue, row.resultUnit as resultUnit MERGE (e:Event {eventId: eventId}) SET e.eventId = eventId, e.patientId = patientId, e.eventName = eventName, e.eventCategory = eventCategory, e.eventDate = eventDate, e.resultValue = resultValue, e.resultUnit = resultUnit
# Out:
# CREATE (e:Event { patientId: '02298368-57b5-11e9-ad52-30582bd09167', eventId: 'cd4d6094-57b7-11e9-99cb-e51ddd026e24', eventName: 'Diastolic BP', eventCategory: 'vitals', eventDate: '2013-12-18T12:57', resultValue: '99.0', resultUnit: 'mmHg', });
# CREATE (e:Event { patientId: '02298368-57b5-11e9-ad52-30582bd09167', eventId: 'dc98c872-57b7-11e9-99cb-e51ddd026e24', eventName: 'O2 Saturation', eventCategory: 'vitals', eventDate: '2013-12-18T12:57', resultValue: '98.0', resultUnit: '%', });
# CREATE (e:Event { patientId: '02298368-57b5-11e9-ad52-30582bd09167', eventId: 'ea8ef398-57b7-11e9-99cb-e51ddd026e24', eventName: 'Pulse', eventCategory: 'vitals', eventDate: '2013-12-18T12:57', resultValue: '72.0', resultUnit: 'BPM', });
# CREATE (e:Event { patientId: '02298368-57b5-11e9-ad52-30582bd09167', eventId: 'f877962c-57b7-11e9-99cb-e51ddd026e24', eventName: 'Respiratory Rate', eventCategory: 'vitals', eventDate: '2013-12-18T12:57', resultValue: '18.0', resultUnit: 'RPM', });
# ...

# %%
df = pd.read_csv('sepsis_linked_events.csv')

# %%
df.shape
# Out:
# (6043553, 4)

# %%
chunks = np.array_split(df, number_of_chunks)

# %%
cnt = 1
for chunk in chunks:
    temp = pd.DataFrame(chunk)
    print(temp.shape)
    out_file = 'output_05_01_2019/sepsis_linked_events_' + str(cnt) + '.csv'
    temp.to_csv(out_file)
    cnt = cnt + 1
# Out:
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# (1008, 4)
# ...
