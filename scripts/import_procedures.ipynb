# %%
import pandas as pd

# %%
df = pd.read_csv('cpt4.csv')
df.columns = ['code','label']
df.head()
# Out:
#     code                         label
# 0  0003T                 Cervicography
# 1  0008T   Upper gi endoscopy w/suture
# 2  0010T     Tb test, gamma interferon
# 3  0016T  Thermotx choroid vasc lesion
# 4  0017T  Photocoagulat macular drusen

# %%
for idx, row in df.iterrows():
    qry = "INSERT INTO modelpatient.labs (cpt,label) VALUES ('" + row['code'] + "','" + row['label'] + "');"
    print(qry)
# Out:
# INSERT INTO modelpatient.labs (cpt,label) VALUES ('0003T','Cervicography');
# INSERT INTO modelpatient.labs (cpt,label) VALUES ('0008T','Upper gi endoscopy w/suture');
# INSERT INTO modelpatient.labs (cpt,label) VALUES ('0010T','Tb test, gamma interferon');
# INSERT INTO modelpatient.labs (cpt,label) VALUES ('0016T','Thermotx choroid vasc lesion');
# INSERT INTO modelpatient.labs (cpt,label) VALUES ('0017T','Photocoagulat macular drusen');
# INSERT INTO modelpatient.labs (cpt,label) VALUES ('0018T','Transcranial magnetic stimul');
# INSERT INTO modelpatient.labs (cpt,label) VALUES ('0019T','Extracorp shock wave tx, ms');
# INSERT INTO modelpatient.labs (cpt,label) VALUES ('0020T','Extracorp shock wave tx, ft');
# INSERT INTO modelpatient.labs (cpt,label) VALUES ('0021T','Fetal oximetry, trnsvag/cerv');
# INSERT INTO modelpatient.labs (cpt,label) VALUES ('0023T','Phenotype drug test, hiv 1');
# INSERT INTO modelpatient.labs (cpt,label) VALUES ('0024T','Transcath cardiac reduction');
# ...
